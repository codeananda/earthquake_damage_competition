# %% [markdown]
# # Lazy Predict Playing
#
# Playing with `lazypredict` ([GitHub](https://github.com/shankarpandala/lazypredict)) to see how well all the classic models do.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from pathlib import Path

# %%
sns.set()

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.6/dist-packages (0.2.7)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from lazypredict) (7.1.2)

# %%
DATA_DIR = Path("/content/drive/MyDrive/Work/Delivery/Current/Earthquake_damage/data")
SUBMISSIONS_DIR = Path(
    "drive/MyDrive/Work/Delivery/Current/Earthquake_damage/submissions"
)

# %%
train_values = pd.read_csv(DATA_DIR / "train_values.csv", index_col="building_id")
train_labels = pd.read_csv(DATA_DIR / "train_labels.csv", index_col="building_id")

# %%
len(train_values) * 0.3
# Out:
# 78180.3

# %%
train_values.sample(n=10, random_state=1)
# Out:
#              geo_level_1_id  ...  has_secondary_use_other
# building_id                  ...
# 360320                   13  ...                        0
# 479622                   26  ...                        0
# 541371                   11  ...                        0
# 429841                   16  ...                        0
# 373726                    3  ...                        0
# 830922                    6  ...                        0
# 800181                   26  ...                        0
# 413022                    6  ...                        0
# 441802                   27  ...                        0
# 8197                     27  ...                        0
#
# [10 rows x 38 columns]

# %%
train_labels.sample(n=10, random_state=1)
# Out:
#              damage_grade
# building_id
# 360320                  2
# 479622                  1
# 541371                  2
# 429841                  3
# 373726                  2
# 830922                  1
# 800181                  2
# 413022                  2
# 441802                  2
# 8197                    3

# %%
train_values = pd.get_dummies(train_values)

# %%
X_sample = train_values.sample(frac=0.1, random_state=1)
y_sample = train_labels.sample(frac=0.1, random_state=1)

# %%
len(X_sample) == len(y_sample)
# Out:
# True

# %% [markdown]
# The class balance is kept after sampling (which is the most important thing).

# %%
train_labels.value_counts(normalize=True, sort=False)
# Out:
# damage_grade
# 1              0.10
# 2              0.57
# 3              0.33
# dtype: float64

# %%
y_sample.value_counts(normalize=True, sort=False)
# Out:
# damage_grade
# 1              0.10
# 2              0.57
# 3              0.34
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from lazypredict.Supervised import LazyClassifier

X_train, X_test, y_train, y_test = train_test_split(
    X_sample, y_sample, test_size=0.3, random_state=123, stratify=y_sample
)

clf = LazyClassifier(verbose=0, custom_metric=None)

models, predictions = clf.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
#   3%|▎         | 1/30 [00:00<00:23,  1.25it/s]
#   7%|▋         | 2/30 [00:01<00:21,  1.27it/s]
#  13%|█▎        | 4/30 [00:33<02:18,  5.32s/it]
#  23%|██▎       | 7/30 [00:33<01:26,  3.75s/it]
#  33%|███▎      | 10/30 [00:35<00:57,  2.86s/it]
#  40%|████      | 12/30 [00:43<00:57,  3.20s/it]
#  43%|████▎     | 13/30 [00:59<01:55,  6.79s/it]
#  47%|████▋     | 14/30 [01:24<03:16, 12.26s/it]
#  50%|█████     | 15/30 [01:24<02:09,  8.63s/it]
#  53%|█████▎    | 16/30 [01:32<01:59,  8.52s/it]
#  57%|█████▋    | 17/30 [01:33<01:19,  6.13s/it]
#  67%|██████▋   | 20/30 [01:33<00:43,  4.31s/it]
#  70%|███████   | 21/30 [01:33<00:27,  3.06s/it]
#  77%|███████▋  | 23/30 [01:35<00:17,  2.53s/it]
#  83%|████████▎ | 25/30 [01:36<00:08,  1.79s/it]
#  87%|████████▋ | 26/30 [01:36<00:05,  1.38s/it]
#  90%|█████████ | 27/30 [02:08<00:31, 10.43s/it]
#  97%|█████████▋| 29/30 [02:11<00:07,  7.83s/it]
# 100%|██████████| 30/30 [02:12<00:00,  4.43s/it]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# BaggingClassifier                  0.67  ...        0.75
# LGBMClassifier                     0.69  ...        1.28
# RandomForestClassifier             0.68  ...        2.49
# ExtraTreesClassifier               0.66  ...        2.21
# DecisionTreeClassifier             0.62  ...        0.16
# NearestCentroid                    0.46  ...        0.05
# AdaBoostClassifier                 0.65  ...        0.80
# XGBClassifier                      0.67  ...        3.53
# ExtraTreeClassifier                0.57  ...        0.05
# LabelSpreading                     0.58  ...       25.02
# BernoulliNB                        0.57  ...        0.06
# LabelPropagation                   0.57  ...       15.15
# KNeighborsClassifier               0.59  ...        7.92
# GaussianNB                         0.39  ...        0.07
# LinearDiscriminantAnalysis         0.57  ...        0.16
# PassiveAggressiveClassifier        0.49  ...        0.11
# SVC                                0.61  ...       31.53
# LogisticRegression                 0.58  ...        0.56
# QuadraticDiscriminantAnalysis      0.37  ...        0.08
# Perceptron                         0.45  ...        0.11
# CalibratedClassifierCV             0.58  ...       31.75
# LinearSVC                          0.58  ...        8.26
# RidgeClassifier                    0.58  ...        0.06
# RidgeClassifierCV                  0.58  ...        0.10
# SGDClassifier                      0.57  ...        0.41
# DummyClassifier                    0.45  ...        0.04
# CheckingClassifier                 0.10  ...        0.05
#
# [27 rows x 5 columns]

# %%
models.sort_values("F1 Score", ascending=False)
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LGBMClassifier                     0.69  ...        1.28
# RandomForestClassifier             0.68  ...        2.49
# BaggingClassifier                  0.67  ...        0.75
# ExtraTreesClassifier               0.66  ...        2.21
# XGBClassifier                      0.67  ...        3.53
# AdaBoostClassifier                 0.65  ...        0.80
# DecisionTreeClassifier             0.62  ...        0.16
# KNeighborsClassifier               0.59  ...        7.92
# LabelSpreading                     0.58  ...       25.02
# LabelPropagation                   0.57  ...       15.15
# ExtraTreeClassifier                0.57  ...        0.05
# BernoulliNB                        0.57  ...        0.06
# SVC                                0.61  ...       31.53
# LogisticRegression                 0.58  ...        0.56
# LinearDiscriminantAnalysis         0.57  ...        0.16
# CalibratedClassifierCV             0.58  ...       31.75
# PassiveAggressiveClassifier        0.49  ...        0.11
# LinearSVC                          0.58  ...        8.26
# RidgeClassifier                    0.58  ...        0.06
# RidgeClassifierCV                  0.58  ...        0.10
# Perceptron                         0.45  ...        0.11
# SGDClassifier                      0.57  ...        0.41
# DummyClassifier                    0.45  ...        0.04
# NearestCentroid                    0.46  ...        0.05
# GaussianNB                         0.39  ...        0.07
# QuadraticDiscriminantAnalysis      0.37  ...        0.08
# CheckingClassifier                 0.10  ...        0.05
#
# [27 rows x 5 columns]

# %%
import lightgbm as lgb
